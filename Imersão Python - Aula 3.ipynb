# %% [markdown]
# ** Aula 3 - Gráficos**

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel("/content/Imersão Python - Tabela de ações - Aula 2.xlsx", sheet_name="Principal")
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume  Variação %  \
# 0           2.26         15.97      9.18      9.56  319,16 M      0.0520
# 1         -12.11         50.56      6.66      6.86   32,65 M      0.0240
# 2           7.64         77.55     40.81     42.34  436,69 M      0.0219
# 3          -4.89         18.85     51.89     53.17  162,55 M      0.0204
# 4          -3.66         20.70     36.37     37.32   73,42 M      0.0203
# ..           ...           ...       ...       ...       ...         ...
# 76        -13.98        -32.72     10.70     11.08   38,19 M     -0.0245
# 77        -23.55        -85.74      8.67      8.95   27,54 M     -0.0246
# 78        -11.57         -2.77     56.04     58.90  624,74 M     -0.0363
# 79        -12.29        -36.83      3.05      3.23  101,46 M     -0.0436
# 80        -34.00        -25.44      5.51      6.02  154,36 M     -0.0807
#
#     Valor Inicial (R$)  Quantidade de ações    Variação $ Resultado  \
# 0             9.030418            515117391  2.418897e+08     Subiu
# 1             6.660156           1110559345  1.775160e+08     Subiu
# 2            41.060769           2379877655  2.140059e+09     Subiu
# 3            51.852215            683452836  7.229463e+08     Subiu
# 4            36.361854            187732538  1.385740e+08     Subiu
# ..                 ...                  ...           ...       ...
# 76           10.978985            533990587 -1.436355e+08    Desceu
# 77            8.919418             94843047 -2.081024e+07    Desceu
# 78           58.358410            853202347 -1.807433e+09    Desceu
# 79            3.209954            525582771 -7.355741e+07    Desceu
# 80            6.439682            198184909 -1.029932e+08    Desceu
#
#      Nome da empresa           Segmento  Idade         Cat_Idade
# 0           Usiminas         Siderurgia   60.0    Entre 50 e 100
# 1      CSN Mineração          Mineração   78.0    Entre 50 e 100
# 2          Petrobras           Petróleo   69.0    Entre 50 e 100
# 3             Suzano   Papel e Celulose   97.0    Entre 50 e 100
# 4       CPFL Energia            Energia  108.0  Mais de 100 anos
# ..               ...                ...    ...               ...
# 76  Carrefour Brasil             Varejo   46.0  Menos de 50 anos
# 77       Casas Bahia             Varejo   68.0    Entre 50 e 100
# 78          Localiza  Aluguel de Carros   49.0  Menos de 50 anos
# 79               CVC            Turismo   49.0  Menos de 50 anos
# 80               GOL         Transporte   21.0  Menos de 50 anos
#
# [81 rows x 20 columns]

# %%
df_total_acoes = pd.read_excel("/content/Imersão Python - Tabela de ações - Aula 2.xlsx", sheet_name="Total_de_acoes")
df_total_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("/content/Imersão Python - Tabela de ações - Aula 2.xlsx", sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_chatgpt = pd.read_excel("/content/Imersão Python - Tabela de ações - Aula 2.xlsx", sheet_name="ChatGPT")
df_chatgpt
# Out:
#              Empresa           Segmento  Idade em Anos
# 0           Usiminas         Siderurgia             60
# 1      CSN Mineração          Mineração             78
# 2          Petrobras           Petróleo             69
# 3             Suzano   Papel e Celulose             97
# 4       CPFL Energia            Energia            108
# ..               ...                ...            ...
# 72  Carrefour Brasil             Varejo             46
# 73       Casas Bahia             Varejo             68
# 74          Localiza  Aluguel de Carros             49
# 75               CVC            Turismo             49
# 76               GOL         Transporte             21
#
# [77 rows x 3 columns]

# %%
df_principal = df_principal[['Ativo', 'Data','Último (R$)',	'Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)':'valor_final', 'Var. Dia (%)':'var_dia_pct'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_principal['Var_pct'] = df_principal['var_dia_pct'] / 100
df_principal['Valor_inicial'] = df_principal['valor_final'] / (df_principal['Var_pct'] + 1)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 7 columns]

# %%
df_principal = df_principal.merge(df_total_acoes, left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica_x Código  Qtde. Teórica_y
# 0      5.151174e+08  USIM5     5.151174e+08
# 1      1.110559e+09  CMIN3     1.110559e+09
# 2      2.379878e+09  PETR3     2.379878e+09
# 3      6.834528e+08  SUZB3     6.834528e+08
# 4      1.877325e+08  CPFE3     1.877325e+08
# ..              ...    ...              ...
# 76     5.339906e+08  CRFB3     5.339906e+08
# 77     9.484305e+07  BHIA3     9.484305e+07
# 78     8.532023e+08  RENT3     8.532023e+08
# 79     5.255828e+08  CVCB3     5.255828e+08
# 80     1.981849e+08  GOLL4     1.981849e+08
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.drop(columns=['Código'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica_x  Qtde. Teórica_y
# 0      5.151174e+08     5.151174e+08
# 1      1.110559e+09     1.110559e+09
# 2      2.379878e+09     2.379878e+09
# 3      6.834528e+08     6.834528e+08
# 4      1.877325e+08     1.877325e+08
# ..              ...              ...
# 76     5.339906e+08     5.339906e+08
# 77     9.484305e+07     9.484305e+07
# 78     8.532023e+08     8.532023e+08
# 79     5.255828e+08     5.255828e+08
# 80     1.981849e+08     1.981849e+08
#
# [81 rows x 8 columns]

# %%
df_principal['Variacao_rs'] = (df_principal['valor_final'] - df_principal['Valor_inicial']) * df_principal['Qtde. Teórica_x']
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica_x  Qtde. Teórica_y   Variacao_rs
# 0      5.151174e+08     5.151174e+08  2.418897e+08
# 1      1.110559e+09     1.110559e+09  1.775160e+08
# 2      2.379878e+09     2.379878e+09  2.140059e+09
# 3      6.834528e+08     6.834528e+08  7.229463e+08
# 4      1.877325e+08     1.877325e+08  1.385740e+08
# ..              ...              ...           ...
# 76     5.339906e+08     5.339906e+08 -1.436355e+08
# 77     9.484305e+07     9.484305e+07 -2.081024e+07
# 78     8.532023e+08     8.532023e+08 -1.807433e+09
# 79     5.255828e+08     5.255828e+08 -7.355741e+07
# 80     1.981849e+08     1.981849e+08 -1.029932e+08
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.drop(columns=['Qtde. Teórica_y'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica_x   Variacao_rs
# 0      5.151174e+08  2.418897e+08
# 1      1.110559e+09  1.775160e+08
# 2      2.379878e+09  2.140059e+09
# 3      6.834528e+08  7.229463e+08
# 4      1.877325e+08  1.385740e+08
# ..              ...           ...
# 76     5.339906e+08 -1.436355e+08
# 77     9.484305e+07 -2.081024e+07
# 78     8.532023e+08 -1.807433e+09
# 79     5.255828e+08 -7.355741e+07
# 80     1.981849e+08 -1.029932e+08
#
# [81 rows x 8 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica_x    Variacao_rs
# 0      515117391.00   241889725.43
# 1     1110559345.00   177515970.30
# 2     2379877655.00  2140059393.53
# 3      683452836.00   722946282.71
# 4      187732538.00   138573955.06
# ..              ...            ...
# 76     533990587.00  -143635530.57
# 77      94843047.00   -20810240.84
# 78     853202347.00 -1807432634.46
# 79     525582771.00   -73557408.06
# 80     198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica_x':'Quantidade_Teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Quantidade_Teorica    Variacao_rs
# 0         515117391.00   241889725.43
# 1        1110559345.00   177515970.30
# 2        2379877655.00  2140059393.53
# 3         683452836.00   722946282.71
# 4         187732538.00   138573955.06
# ..                 ...            ...
# 76        533990587.00  -143635530.57
# 77         94843047.00   -20810240.84
# 78        853202347.00 -1807432634.46
# 79        525582771.00   -73557408.06
# 80        198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Quantidade_Teorica'] = df_principal['Quantidade_Teorica'].astype(int)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Quantidade_Teorica    Variacao_rs
# 0            515117391   241889725.43
# 1           1110559345   177515970.30
# 2           2379877655  2140059393.53
# 3            683452836   722946282.71
# 4            187732538   138573955.06
# ..                 ...            ...
# 76           533990587  -143635530.57
# 77            94843047   -20810240.84
# 78           853202347 -1807432634.46
# 79           525582771   -73557408.06
# 80           198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Status'] = df_principal['Variacao_rs'].apply(lambda x: 'Subiu' if x > 0 else ('Desceu' if x < 0 else 'Estável'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Quantidade_Teorica    Variacao_rs  Status
# 0            515117391   241889725.43   Subiu
# 1           1110559345   177515970.30   Subiu
# 2           2379877655  2140059393.53   Subiu
# 3            683452836   722946282.71   Subiu
# 4            187732538   138573955.06   Subiu
# ..                 ...            ...     ...
# 76           533990587  -143635530.57  Desceu
# 77            94843047   -20810240.84  Desceu
# 78           853202347 -1807432634.46  Desceu
# 79           525582771   -73557408.06  Desceu
# 80           198184909  -102993202.62  Desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal = df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Quantidade_Teorica    Variacao_rs  Status              Nome
# 0            515117391   241889725.43   Subiu          Usiminas
# 1           1110559345   177515970.30   Subiu     CSN Mineração
# 2           2379877655  2140059393.53   Subiu         Petrobras
# 3            683452836   722946282.71   Subiu            Suzano
# 4            187732538   138573955.06   Subiu      CPFL Energia
# ..                 ...            ...     ...               ...
# 76           533990587  -143635530.57  Desceu  Carrefour Brasil
# 77            94843047   -20810240.84  Desceu       Casas Bahia
# 78           853202347 -1807432634.46  Desceu          Localiza
# 79           525582771   -73557408.06  Desceu               CVC
# 80           198184909  -102993202.62  Desceu               GOL
#
# [81 rows x 10 columns]

# %%
df_principal = df_principal.merge(df_chatgpt, left_on='Nome', right_on='Empresa', how='left')
df_principal = df_principal.drop(columns=['Empresa'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Quantidade_Teorica    Variacao_rs  Status              Nome  \
# 0            515117391   241889725.43   Subiu          Usiminas
# 1           1110559345   177515970.30   Subiu     CSN Mineração
# 2           2379877655  2140059393.53   Subiu         Petrobras
# 3            683452836   722946282.71   Subiu            Suzano
# 4            187732538   138573955.06   Subiu      CPFL Energia
# ..                 ...            ...     ...               ...
# 76           533990587  -143635530.57  Desceu  Carrefour Brasil
# 77            94843047   -20810240.84  Desceu       Casas Bahia
# 78           853202347 -1807432634.46  Desceu          Localiza
# 79           525582771   -73557408.06  Desceu               CVC
# 80           198184909  -102993202.62  Desceu               GOL
#
#              Segmento  Idade em Anos
# 0          Siderurgia          60.00
# 1           Mineração          78.00
# 2            Petróleo          69.00
# 3    Papel e Celulose          97.00
# 4             Energia         108.00
# ..                ...            ...
# 76             Varejo          46.00
# 77             Varejo          68.00
# 78  Aluguel de Carros          49.00
# 79            Turismo          49.00
# 80         Transporte          21.00
#
# [81 rows x 12 columns]

# %%
df_principal['Idade_categoria'] = df_principal['Idade em Anos'].apply(lambda x: 'Mais de 100' if x > 100 else ('Menos de 50' if x < 50 else 'Entre 50 e 100'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Quantidade_Teorica    Variacao_rs  Status              Nome  \
# 0            515117391   241889725.43   Subiu          Usiminas
# 1           1110559345   177515970.30   Subiu     CSN Mineração
# 2           2379877655  2140059393.53   Subiu         Petrobras
# 3            683452836   722946282.71   Subiu            Suzano
# 4            187732538   138573955.06   Subiu      CPFL Energia
# ..                 ...            ...     ...               ...
# 76           533990587  -143635530.57  Desceu  Carrefour Brasil
# 77            94843047   -20810240.84  Desceu       Casas Bahia
# 78           853202347 -1807432634.46  Desceu          Localiza
# 79           525582771   -73557408.06  Desceu               CVC
# 80           198184909  -102993202.62  Desceu               GOL
#
#              Segmento  Idade em Anos Idade_categoria
# 0          Siderurgia          60.00  Entre 50 e 100
# 1           Mineração          78.00  Entre 50 e 100
# 2            Petróleo          69.00  Entre 50 e 100
# 3    Papel e Celulose          97.00  Entre 50 e 100
# 4             Energia         108.00     Mais de 100
# ..                ...            ...             ...
# 76             Varejo          46.00     Menos de 50
# 77             Varejo          68.00  Entre 50 e 100
# 78  Aluguel de Carros          49.00     Menos de 50
# 79            Turismo          49.00     Menos de 50
# 80         Transporte          21.00     Menos de 50
#
# [81 rows x 13 columns]

# %% [markdown]
# **Análises**

# %%
# Calculando a maior variação
maior = df_principal['Variacao_rs'].max()

# Calculando a menor variação
menor = df_principal['Variacao_rs'].min()

# Calculando a média de variação
media = df_principal['Variacao_rs'].mean()

# Filtrando as linhas de quem subiu e calculando a média
media_subiu = df_principal[df_principal['Status'] == 'Subiu']['Variacao_rs'].mean()

# Filtrando as linhas de quem desceu e calculando a média
media_desceu = df_principal[df_principal['Status'] == 'Desceu']['Variacao_rs'].mean()

# Imprimindo os resultados
print(f"Maior\tR$ {maior:,.2f}")
print(f"Menor\tR$ {menor:,.2f}")
print(f"Média\tR$ {media:,.2f}")
print(f"Média de quem subiu\tR$ {media_subiu:,.2f}")
print(f"Média de quem desceu\tR$ {media_desceu:,.2f}")
# Out:
# Maior	R$ 4,762,926,995.25
# Menor	R$ -1,807,432,634.46
# Média	R$ 165,190,210.48
# Média de quem subiu	R$ 448,164,250.23
# Média de quem desceu	R$ -181,109,141.75

# %%
df_principal_subiu = df_principal[df_principal['Status'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  Valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# 5   PRIO3 2024-01-26        45.69         1.98     0.02          44.80
# 6   PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 7   VALE3 2024-01-26        69.50         1.66     0.02          68.37
# 8   MULT3 2024-01-26        28.19         1.58     0.02          27.75
# 9   ITUB4 2024-01-26        32.81         1.48     0.01          32.33
# 10  RDOR3 2024-01-26        27.56         1.43     0.01          27.17
# 11  BRKM5 2024-01-26        18.55         1.42     0.01          18.29
# 12  AZUL4 2024-01-26        14.27         1.42     0.01          14.07
# 13  RRRP3 2024-01-26        28.75         1.41     0.01          28.35
# 14  EQTL3 2024-01-26        35.32         1.34     0.01          34.85
# 15  CSNA3 2024-01-26        18.16         1.33     0.01          17.92
# 16  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
# 17  UGPA3 2024-01-26        28.31         1.28     0.01          27.95
# 18  MRVE3 2024-01-26         8.08         1.25     0.01           7.98
# 19  ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 20  BBDC4 2024-01-26        15.52         1.04     0.01          15.36
# 21  BEEF3 2024-01-26         7.19         0.98     0.01           7.12
# 22  PCAR3 2024-01-26         4.14         0.97     0.01           4.10
# 23  BRFS3 2024-01-26        14.61         0.96     0.01          14.47
# 24  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 25  RAIL3 2024-01-26        22.64         0.84     0.01          22.45
# 26  CIEL3 2024-01-26         4.90         0.82     0.01           4.86
# 27  DXCO3 2024-01-26         7.81         0.77     0.01           7.75
# 28  TIMS3 2024-01-26        17.52         0.74     0.01          17.39
# 29  BRAP4 2024-01-26        23.22         0.73     0.01          23.05
# 30  LWSA3 2024-01-26         5.55         0.72     0.01           5.51
# 31  RECV3 2024-01-26        23.83         0.71     0.01          23.66
# 32  ITSA4 2024-01-26        10.01         0.70     0.01           9.94
# 33  BBAS3 2024-01-26        56.97         0.68     0.01          56.59
# 34  RADL3 2024-01-26        26.16         0.61     0.01          26.00
# 35  GOAU4 2024-01-26        10.08         0.59     0.01          10.02
# 36  CSAN3 2024-01-26        18.57         0.59     0.01          18.46
# 37  JBSS3 2024-01-26        24.34         0.57     0.01          24.20
# 38  MGLU3 2024-01-26         2.08         0.48     0.00           2.07
# 39  BBDC3 2024-01-26        13.75         0.36     0.00          13.70
# 40  GGBR4 2024-01-26        21.84         0.27     0.00          21.78
# 41  RAIZ4 2024-01-26         3.74         0.26     0.00           3.73
# 42  CPLE6 2024-01-26        10.07         0.19     0.00          10.05
# 43  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
#
#     Quantidade_Teorica   Variacao_rs Status                  Nome  \
# 0            515117391  241889725.43  Subiu              Usiminas
# 1           1110559345  177515970.30  Subiu         CSN Mineração
# 2           2379877655 2140059393.53  Subiu             Petrobras
# 3            683452836  722946282.71  Subiu                Suzano
# 4            187732538  138573955.06  Subiu          CPFL Energia
# 5            800010734  709687498.18  Subiu              PetroRio
# 6           4566445852 3103136291.22  Subiu             Petrobras
# 7           4196924316 4762926995.25  Subiu                  Vale
# 8            268505432  117732680.08  Subiu             Multiplan
# 9           4801593832 2297591984.33  Subiu         Itaú Unibanco
# 10          1168230366  453917907.01  Subiu             Rede D'Or
# 11           265877867   69054317.64  Subiu               Braskem
# 12           327593725   65452205.55  Subiu                  Azul
# 13           235665566   94204643.35  Subiu          3R Petroleum
# 14          1095587251  511671895.45  Subiu    Equatorial Energia
# 15           600865451  143220991.46  Subiu  Siderúrgica Nacional
# 16           289347914   72295838.99  Subiu                 YDUQS
# 17          1086411192  388705223.96  Subiu              Ultrapar
# 18           376187582   37525872.38  Subiu                   MRV
# 19            62305891   41021792.09  Subiu                Arezzo
# 20          5146576868  822148336.41  Subiu        Banco Bradesco
# 21           261036182   18214628.10  Subiu               Minerva
# 22           159430826    6340916.22  Subiu   Grupo Pão de Açúcar
# 23          1677525446  233045769.57  Subiu                   BRF
# 24           423091712  188965307.06  Subiu                  Vivo
# 25          1218352541  229771333.63  Subiu                  Rumo
# 26          1095462329   43657683.38  Subiu                 Cielo
# 27           302768240   18068446.61  Subiu                 Dexco
# 28           807896814  103972807.37  Subiu                   TIM
# 29           251003438   42238249.54  Subiu             Bradespar
# 30           393173139   15598886.65  Subiu               Locaweb
# 31           275005663   46201006.00  Subiu        PetroRecôncavo
# 32          5372783971  373853994.88  Subiu                Itaúsa
# 33          1420949112  546752087.99  Subiu       Banco do Brasil
# 34          1275798515  202352473.74  Subiu          RaiaDrogasil
# 35           660411219   39045606.94  Subiu    Metalúrgica Gerdau
# 36          1168097881  127229653.18  Subiu                 Cosan
# 37          1134986472  156573285.43  Subiu                   JBS
# 38          2867627068   28493619.27  Subiu        Magazine Luiza
# 39          1500728902   74019610.05  Subiu        Banco Bradesco
# 40          1118525506   65779607.10  Subiu                Gerdau
# 41          1193047233   11571106.42  Subiu                Raízen
# 42          1679335290   32069789.50  Subiu                 Copel
# 43           421383330    4131341.16  Subiu           Grupo Vamos
#
#             Segmento  Idade em Anos Idade_categoria
# 0         Siderurgia          60.00  Entre 50 e 100
# 1          Mineração          78.00  Entre 50 e 100
# 2           Petróleo          69.00  Entre 50 e 100
# 3   Papel e Celulose          97.00  Entre 50 e 100
# 4            Energia         108.00     Mais de 100
# 5           Petróleo          10.00     Menos de 50
# 6           Petróleo          69.00  Entre 50 e 100
# 7          Mineração          80.00  Entre 50 e 100
# 8        Imobiliário          50.00  Entre 50 e 100
# 9         Financeiro          13.00     Menos de 50
# 10             Saúde          51.00  Entre 50 e 100
# 11           Químico          19.00     Menos de 50
# 12        Transporte          14.00     Menos de 50
# 13          Petróleo           8.00     Menos de 50
# 14           Energia          23.00     Menos de 50
# 15        Siderurgia          82.00  Entre 50 e 100
# 16          Educação          73.00  Entre 50 e 100
# 17           Energia          83.00  Entre 50 e 100
# 18       Imobiliário          42.00     Menos de 50
# 19              Moda          50.00  Entre 50 e 100
# 20        Financeiro          78.00  Entre 50 e 100
# 21       Alimentício          30.00     Menos de 50
# 22       Alimentício          65.00  Entre 50 e 100
# 23       Alimentício          84.00  Entre 50 e 100
# 24  Telecomunicações          22.00     Menos de 50
# 25         Logística          12.00     Menos de 50
# 26        Financeiro          23.00     Menos de 50
# 27        Financeiro          25.00     Menos de 50
# 28  Telecomunicações          28.00     Menos de 50
# 29        Financeiro          29.00     Menos de 50
# 30        Tecnologia          25.00     Menos de 50
# 31          Petróleo           9.00     Menos de 50
# 32        Financeiro          55.00  Entre 50 e 100
# 33        Financeiro         213.00     Mais de 100
# 34             Saúde         118.00     Mais de 100
# 35        Siderurgia         120.00     Mais de 100
# 36           Energia          89.00  Entre 50 e 100
# 37       Alimentício          69.00  Entre 50 e 100
# 38            Varejo          64.00  Entre 50 e 100
# 39        Financeiro          78.00  Entre 50 e 100
# 40               NaN            NaN  Entre 50 e 100
# 41           Energia          11.00     Menos de 50
# 42           Energia          67.00  Entre 50 e 100
# 43         Logística          15.00     Menos de 50

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#             Segmento   Variacao_rs
# 0        Alimentício  414174599.32
# 1           Educação   72295838.99
# 2            Energia 1209821623.57
# 3         Financeiro 4218330393.19
# 4        Imobiliário  155258552.46
# 5          Logística  233902674.79
# 6          Mineração 4940442965.55
# 7               Moda   41021792.09
# 8   Papel e Celulose  722946282.71
# 9           Petróleo 6093288832.26
# 10           Químico   69054317.64
# 11             Saúde  656270380.75
# 12        Siderurgia  424156323.83
# 13        Tecnologia   15598886.65
# 14  Telecomunicações  292938114.42
# 15        Transporte   65452205.55
# 16            Varejo   28493619.27

# %%
df_analise_saldo = df_principal.groupby('Status')['Variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#     Status    Variacao_rs
# 0   Desceu -6338819961.32
# 1  Estável           0.00
# 2    Subiu 19719227010.14

# %%
fig = px.bar(df_analise_saldo, x='Status', y='Variacao_rs', text='Variacao_rs', title='Variação Reais por Resultado')
fig.show()

# %% [markdown]
# Desafio: 1. Pesquisar como exibir os números no gráfico com uma separação mais clara.

# %%
df_analise_saldo['Variacao_rs'] = df_analise_saldo['Variacao_rs'].apply(lambda x: f'R$ {x:,.2f}')
df_analise_saldo
# Out:
#     Status           Variacao_rs
# 0   Desceu  R$ -6,338,819,961.32
# 1  Estável               R$ 0.00
# 2    Subiu  R$ 19,719,227,010.14

# %%
fig = px.bar(df_analise_saldo, x='Status', y='Variacao_rs', text='Variacao_rs', title='Variação Reais por Resultado')
fig.show()

# %% [markdown]
# Desafio 2. Fazer um gráfico de pizza com o def_analise_segmentos.

# %%
fig = px.pie(df_analise_segmento, names='Segmento', values='Variacao_rs', title='Variação Reais por Segmento')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="62e568ab-06dc-4845-be3b-b71db5d5875b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62e568ab-06dc-4845-be3b-b71db5d5875b")) {                    Plotly.newPlot(                        "62e568ab-06dc-4845-be3b-b71db5d5875b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Segmento=%{label}\u003cbr\u003eVariacao_rs=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Aliment\u00edcio","Educa\u00e7\u00e3o","Energia","Financeiro","Imobili\u00e1rio","Log\u00edstica","Minera\u00e7\u00e3o","Moda","Papel e Celulose","Petr\u00f3leo","Qu\u00edmico","Sa\u00fade","Siderurgia","Tecnologia","Telecomunica\u00e7\u00f5es","Transporte","Varejo"],"legendgroup":"","name":"","showlegend":true,"values":[414174599.3155935,72295838.98616095,1209821623.5672965,4218330393.192739,155258552.45570898,233902674.79257408,4940442965.550434,41021792.09077153,722946282.7090385,6093288832.2628355,69054317.63603853,656270380.7530686,424156323.82968384,15598886.650556229,292938114.42357796,65452205.552800186,28493619.274394516],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{" ...
